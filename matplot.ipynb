# %% [markdown]
# <a href="https://colab.research.google.com/github/sasi22002/EMS/blob/main/matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3,3.1, 4, 4.5,5]
y = [2, 3, 5, 8,7, 10,11]

# Create a line plot
plt.plot(x, y, marker='o')
plt.title('Simple Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {
    'x': [1, 2, 3, 4, 5],
    'y': [2, 3, 5, 7, 11]
}

# Convert the data to a pandas DataFrame
df = pd.DataFrame(data)

# Create a scatter plot with a regression line
sns.regplot(x='x', y='y', data=df)
plt.title('Scatter Plot with Regression Line')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = [0, 6]
ypoints = [0, 250]

plt.plot(ypoints, xpoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2,1])
plt.title("Simple Plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints,'o',ms=11,mec='r',mfc='r',ls="dotted",color='g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])
xpoints = np.array([1, 2, 9, 5])
plt.subplot(2, 2, 1)
plt.plot(xpoints,ypoints,'o',ls='dotted',lw='2.1',color='red',mec='b')
# plt.plot(ypoints,'o',ls='--',lw='2.1',color='green',mec='b')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1,loc='right')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.grid()
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

#new subplot func start from here
plt.subplot(2, 2, 4)
plt.plot(xpoints,ypoints,'o',ls='dotted',lw='2.1',color='red',mec='b')
# plt.plot(ypoints,'o',ls='--',lw='2.1',color='green',mec='b')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1,loc='right')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.grid()
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.suptitle("MY SHOP")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
x3 = np.array([6, 2, 7, 11])
y3 = np.array([0, 1, 2, 3])

plt.plot(x1, y1, x2, y2,x3,y3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y)


#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 3)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
colors = np.array(["red","green","red","red","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c = colors)
plt.xlabel("speed")
plt.ylabel("range")
plt.title("vehicle tracker")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([100, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, c=colors, cmap='Accent',s=sizes,alpha=0.8)

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color='r',width=0.1)
plt.xlabel("speed")
plt.ylabel("range")
plt.title("vehicle tracker")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)
plt.hist(x,color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()
